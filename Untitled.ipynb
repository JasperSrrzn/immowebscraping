# %%
import pandas as pd

# %%
def get_price(x):
    return int(re.sub("[^0-9]", "", x))

# %%
df = pd.read_csv('data.csv')

# %%
filtered = df[(df["living area (m²)"]!='(residential, urban or rural)') & (df["bedrooms"].notnull())]

# %%
filtered = filtered[(filtered["bedrooms"]==3) & (filtered["building condition"]=="good")]

# %%
len(filtered)
# Out:
# 98

# %%
filtered["price"] = filtered.apply(lambda x: get_price(x["price"]),axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-1db0a7984e83> in <module>
# ----> 1 filtered["price"] = filtered.apply(lambda x: get_price(x["price"]),axis=1)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
# ...

# %%
filtered
# Out:
#       price  construction year building condition street frontage width  \
# 5    385000                NaN               good                   NaN
# 11   289000             1948.0               good                   NaN
# 17   998000             1957.0               good                   NaN
# 18   998000             1957.0               good                   NaN
# 20   475000             2019.0               good                   NaN
# ..      ...                ...                ...                   ...
# 731  237000             1931.0               good                   5 m
# 734  216000             1960.0               good                   NaN
# 737  289000             1977.0               good                   NaN
# 740  329000             1997.0               good                   NaN
# 741  369000             2002.0               good                  10 m
#
#      number of frontages living area (m²)  bedrooms  bathrooms  toilets  \
# ...

# %%
filtered.hist(bins=50, column="price", figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'price'}>]], dtype=object)
